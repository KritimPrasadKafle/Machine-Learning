# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Downloads\nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Downloads\weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017', '1/3/2017', '1/3/2017', '1/4/2017', '1/6/2017'],
    'temperature': [32,35,28,24,32],
    'windspeed': [6,7,2,7,4],
    'event': ['Rain', 'Sunny', 'Snow', 'Rain', 'Sunny']
}

df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df.shape
# Out:
# (5, 4)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 5

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 4  1/6/2017           32          4  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
import numpy as np
s = np.arange(5, dtype = complex)
s
# Out:
# array([0.+0.j, 1.+0.j, 2.+0.j, 3.+0.j, 4.+0.j])

# %%
s.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_115148\2491175235.py in <module>
# ----> 1 s.type()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
dir(s)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Rain
# 4    Sunny
# Name: event, dtype: object

# %%
type(s)
# Out:
# numpy.ndarray

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df[['event', 'day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/3/2017
# 2   Snow  1/3/2017
# 3   Rain  1/4/2017
# 4  Sunny  1/6/2017

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['temperature'].describe()
# Out:
# count     5.000000
# mean     30.200000
# std       4.266146
# min      24.000000
# 25%      28.000000
# 50%      32.000000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df['temperature'].mean()
# Out:
# 30.2

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     5.000000   5.000000
# mean     30.200000   5.200000
# std       4.266146   2.167948
# min      24.000000   2.000000
# 25%      28.000000   4.000000
# 50%      32.000000   6.000000
# 75%      32.000000   7.000000
# max      35.000000   7.000000

# %%
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 4  1/6/2017           32          4  Sunny

# %%
df[df.temperature==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/3/2017           35          7  Sunny

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/3/2017           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/3/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Rain
# 1/6/2017           32          4  Sunny

# %%
df[['temperature', 'windspeed']][df.loc['1/4/2017']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_115148\298438939.py in <module>
# ----> 1 df[['temperature', 'windspeed']][df.loc['1/4/2017']]
#
# C:\New folder\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# C:\New folder\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %%
df.reset_index()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Rain
# 4  1/6/2017           32          4  Sunny

# %%
df.set_index('event', inplace=True)

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/3/2017           35          7
# Snow   1/3/2017           28          2
# Rain   1/4/2017           24          7
# Sunny  1/6/2017           32          4

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Downloads\nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df = pd.read_excel()

# %%
weather_data={
    'day': ['1/1/2017','2/3/2023'],
    'temperature': [32,45],
    'event': ['Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  2/3/2023           45  Sunny

# %%
weather_data={
    ('1/1/2017',34,8,'Rain'),
    ('2/3/2023',32,7,'Sunny'),
    ('4/2/2024',28, 'Snow')
}
df = pd.DataFrame(weather_data)
