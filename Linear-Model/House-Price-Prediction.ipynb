# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = {
    "area" : [2000, 4000, 6000, 8000],
    "price" : [55000, 40000, 60000, 90000],
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    area  price
# 0  2000  55000
# 1  4000  40000
# 2  6000  60000
# 3  8000  90000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price, color = 'red', marker = '+')
plt.plot(df.area, reg.predict(df[['area']]),color = 'blue')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = linear_model.LinearRegression()
# training the data
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
input_data = np.array([3000]).reshape(-1,1)

# %%
prediction = reg.predict(input_data)
# Out:
# C:\New folder\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [48750.]

# %%
reg.coef_
# Out:
# array([6.25])

# %%
reg.intercept_
# Out:
# 30000.000000000015

# %%
# y = m*x+b
6.25*3000 + 30000.000000000015
# Out:
# 48750.000000000015

# %%
d = {
    "areas" : [324,432,432,65,8,76,5,325,532],
    
}

# data = {
#     "area" : [2000, 4000, 6000, 8000],
#     "price" : [55000, 40000, 60000, 90000],
# }

# %%
datas =pd.DataFrame(d)

# %%
datas.head(3)
# Out:
#    areas
# 0    324
# 1    432
# 2    432

# %%
p = np.array([d]).reshape(-1,1)

# %%
p = np.array([2000]).reshape(-1,1)
reg.predict(p)
# Out:
# C:\New folder\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([42500.])

# %%
d['price']
