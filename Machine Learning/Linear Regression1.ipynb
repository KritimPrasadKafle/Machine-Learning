# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

radio = np.random.uniform(0, 100, 100)

noise = np.random.normal(0, 5, 100)

fanta = np.random.normal(0,4,100)
sales = 0.5 * radio + noise

df = pd.DataFrame({
    'radio': radio,
    'Sales': sales,
    'fanta': fanta
})

# %%
df
# Out:
#         radio      Sales      fanta
# 0   37.454012  19.162241   0.052008
# 1   95.071431  46.040679   5.814136
# 2   73.199394  37.058501  -1.058627
# 3   59.865848  19.995080  10.880677
# 4   15.601864   6.702573   2.502669
# ..        ...        ...        ...
# 95  49.379560  20.610728  -5.743449
# 96  52.273283  25.751133   4.652655
# 97  42.754102  23.082811   0.040932
# 98   2.541913   2.654410  -3.926035
# 99  10.789143   9.530488   1.848414
#
# [100 rows x 3 columns]

# %%
model = LinearRegression()

# %%
X = df[['radio', 'fanta']]
y = df['Sales']

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.9081896357887098

# %%
model.predict([[34,76]])
# Out:
# /home/kritim/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.5499918])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
