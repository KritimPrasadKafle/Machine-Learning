# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
inputs = df.drop(['PassengerId', 'Name','SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis = 'columns')
inputs
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
inputs.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
inputs.fillna(inputs['Age'].mean(), inplace = True)

# %%
dir(inputs)
# Out:
# ['Age',
#  'Fare',
#  'Pclass',
#  'Sex',
#  'Survived',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
column = inputs.columns

# %%
column
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
inputs.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
inputs.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le_Sex = LabelEncoder()

# %%
inputs['Sex_new'] = le_Sex.fit_transform(inputs['Sex'])

# %%
inputs.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare  Sex_new
# 0         0       3    male  22.0   7.2500        1
# 1         1       1  female  38.0  71.2833        0
# 2         1       3  female  26.0   7.9250        0
# 3         1       1  female  35.0  53.1000        0
# 4         0       3    male  35.0   8.0500        1

# %%
input_new = inputs.drop(['Sex'], axis = 'columns')

# %%
input_new
# Out:
#      Survived  Pclass        Age     Fare  Sex_new
# 0           0       3  22.000000   7.2500        1
# 1           1       1  38.000000  71.2833        0
# 2           1       3  26.000000   7.9250        0
# 3           1       1  35.000000  53.1000        0
# 4           0       3  35.000000   8.0500        1
# ..        ...     ...        ...      ...      ...
# 886         0       2  27.000000  13.0000        1
# 887         1       1  19.000000  30.0000        0
# 888         0       3  29.699118  23.4500        0
# 889         1       1  26.000000  30.0000        1
# 890         0       3  32.000000   7.7500        1
#
# [891 rows x 5 columns]

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
input_new
# Out:
#      Survived  Pclass        Age     Fare  Sex_new
# 0           0       3  22.000000   7.2500        1
# 1           1       1  38.000000  71.2833        0
# 2           1       3  26.000000   7.9250        0
# 3           1       1  35.000000  53.1000        0
# 4           0       3  35.000000   8.0500        1
# ..        ...     ...        ...      ...      ...
# 886         0       2  27.000000  13.0000        1
# 887         1       1  19.000000  30.0000        0
# 888         0       3  29.699118  23.4500        0
# 889         1       1  26.000000  30.0000        1
# 890         0       3  32.000000   7.7500        1
#
# [891 rows x 5 columns]

# %%
inputs_new = input_new.drop(['Survived'], axis = 'columns')

# %%
target = input_new['Survived']
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(model)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
model.fit(inputs_new, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_new, target)
# Out:
# 0.9797979797979798

# %%
model.predict([[3,22,7.25,1]])
# Out:
# C:\New folder\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
